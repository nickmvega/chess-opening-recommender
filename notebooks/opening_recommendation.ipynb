# %% [markdown]
# # Chess Opening Recommender : Opening Recommendation based on user

# %% [markdown]
# ## Overview
# Use the **Top 5 stylistic peers** to find which openings they play most often—and most successfully—as White and as Black.

# %%
import pandas as pd
from pathlib import Path

DATA_DIR = Path("/Users/nicholasvega/Downloads/chess-opening-recommender/src/data")
ELITE_PARQUET = DATA_DIR / "lichess_elite_2025-05.parquet"

# %%
elite_df = pd.read_parquet(ELITE_PARQUET)
elite_df
# Out:
#                     white         black   result  eco  \
# 0        eNErGyOFbEiNGbOT  Nikitosik-ai  1/2-1/2  A00
# 1         Chessanonymous1     Ariel_mlr      1-0  A45
# 2              Kyreds_pet     OlympusCz      1-0  B90
# 3                rtahmass      Mettigel      0-1  C72
# 4                CruelKen    tomlesspit  1/2-1/2  D38
# ..                    ...           ...      ...  ...
# 495  Ukraine-team-creator  Nikitosik-ai  1/2-1/2  A00
# 496      Elretornodelmore  chac_sparrow      0-1  B43
# 497              colinbot      Fruity23  1/2-1/2  C65
# 498               mmc1975   ShramovIgor      1-0  B01
# 499                 mux77     ALLinAL30      1-0  A05
#
#                                                opening    utc_date  utc_time  \
# 0                                      Clemenz Opening  2025.05.01  00:00:15
# 1                                    Trompowsky Attack  2025.05.01  00:00:54
# 2    Sicilian Defense: Najdorf Variation, English A...  2025.05.01  00:00:45
# 3    Ruy Lopez: Morphy Defense, Modern Steinitz Def...  2025.05.01  00:01:09
# 4    Queen's Gambit Declined: Ragozin Defense, Alek...  2025.05.01  00:01:12
# ..                                                 ...         ...       ...
# 495                                  Hungarian Opening  2025.05.01  02:11:52
# 496  Sicilian Defense: Kan Variation, Knight Variation  2025.05.01  02:11:49
# 497                          Ruy Lopez: Berlin Defense  2025.05.01  02:11:39
# 498       Scandinavian Defense: Gubinsky-Melts Defense  2025.05.01  02:11:29
# 499                               King's Indian Attack  2025.05.01  02:12:25
#
#     time_control                                              moves
# 0          180+0  [h2h3, e7e5, e2e4, g8f6, b1c3, f8b4, a2a3, b4a...
# 1          180+0  [d2d4, g8f6, c1g5, d7d5, g5f6, e7f6, e2e3, f8d...
# 2          180+0  [e2e4, c7c5, g1f3, d7d6, d2d4, c5d4, f3d4, g8f...
# 3          180+0  [e2e4, e7e5, g1f3, b8c6, f1b5, a7a6, b5a4, d7d...
# 4          180+2  [g1f3, d7d5, d2d4, g8f6, c2c4, e7e6, b1c3, f8b...
# ..           ...                                                ...
# 495        180+0  [g2g3, d7d5, d2d4, g8f6, a2a3, e7e6, c2c4, d5c...
# 496        180+0  [e2e4, c7c5, g1f3, e7e6, d2d4, c5d4, f3d4, a7a...
# 497        180+2  [e2e4, e7e5, g1f3, b8c6, f1b5, g8f6, d2d3, f8c...
# 498        180+2  [e2e4, d7d5, e4d5, d8d5, b1c3, d5d6, d2d4, g8f...
# 499        180+0  [g1f3, d7d5, g2g3, g8f6, f1g2, c7c6, e1g1, c8f...
#
# [500 rows x 9 columns]

# %%
top_peers = pd.DataFrame({
    'player': ['Attack2GM','Neftegor','Arteler','Sakh_chess_2','rtahmass']
})

# %% [markdown]
# ## 4.1 Filter games to be peer games only

# %%
def get_peer_games(elite_df: pd.DataFrame, peer_list: list[str]) -> pd.DataFrame:
    """
    Return games where either White or Black is in the given peer_list.

    Args:
        elite_df: DataFrame containing columns 'white' and 'black'.
        peer_list: list of player usernames to filter by.

    Returns:
        Subset of elite_df with only games involving peers.
    """
    return elite_df[elite_df['white'].isin(peer_list) | elite_df['black'].isin(peer_list)].copy()

# %%
peer_games = get_peer_games(elite_df, top_peers['player'].tolist())
peer_games
# Out:
#                    white               black   result  eco  \
# 3               rtahmass            Mettigel      0-1  C72
# 18              rtahmass             Arteler      1-0  C06
# 41               nickVet             Arteler      1-0  A00
# 44              rtahmass       SugarMagnolia  1/2-1/2  B80
# 55             MityshevS        Sakh_chess_2      1-0  B12
# 68               Panesso            rtahmass      0-1  D35
# 76          Sakh_chess_2         ice2breaker      1-0  E73
# 81               Arteler     notrashopenings      0-1  C67
# 96                LAVT96            rtahmass      0-1  B12
# 117         Sakh_chess_2  Surreptitiously421      0-1  E73
# 122  PerpetuallyLearning            rtahmass      1-0  B11
# 129               lestri        Sakh_chess_2      1-0  A11
# 138         Sakh_chess_2            tiranooo      1-0  D35
# 150             rtahmass    Elretornodelmore      0-1  C07
# 151            Sanamente        Sakh_chess_2      0-1  B10
# 170             rtahmass          Accusefive      0-1  B32
# 192         Sakh_chess_2             Arteler      0-1  D10
# 203         Grappler1990            rtahmass      0-1  B12
# 220              Arteler      padzsyychess14      1-0  C06
# 221         chessgod-123        Sakh_chess_2      0-1  D14
# 234             rtahmass    titanshahmat2003      1-0  C82
# 242         Sakh_chess_2             Ruoxiax      0-1  D35
# 247           AAlmeidaTX             Arteler      0-1  C20
# 254             avchess1            rtahmass      1-0  B12
# 258           Accusefive        Sakh_chess_2      0-1  D10
# 270              Arteler            Eggplant      1-0  C10
# 277              Arteler            rtahmass      1-0  B13
# 296             rtahmass       InnocuousMate      1-0  B42
# 297              Arteler   ChessBoiJasonUSCA      1-0  B14
# 317              Kysylyn             Arteler      1-0  C00
# 318             rtahmass    Elretornodelmore      1-0  B00
# 337         MyDeletedAcc            rtahmass      1-0  B12
# 340      notrashopenings             Arteler      0-1  D11
# 353              Arteler             TheM0nk      1-0  B30
# 364             rtahmass    Elretornodelmore      1-0  C03
# 368       thundertwister            rtahmass      1-0  A13
# 374      notrashopenings            rtahmass      1-0  E04
# 376             rdarruda           Attack2GM      1-0  A41
# 378               micfel             Arteler      1-0  C06
# 398             rtahmass        MsBlunderful  1/2-1/2  C07
# 399            Attack2GM               tm313      1-0  A45
# 423             rtahmass            Neftegor      1-0  C03
# 426       JuanitoAlimana           Attack2GM      0-1  B06
# 442             Zeraw000             Arteler      0-1  C15
# 444      MrTroutstanding            Neftegor      0-1  C01
# 446             Ellaijio            rtahmass      1-0  B15
# 461         Annaconda116        Sakh_chess_2      0-1  D14
# 462             Neftegor          ludusTrash      1-0  A33
# 464              Arteler          gmlectures      0-1  C77
# 467            Attack2GM     shirokirina2010      0-1  A45
# 468      notrashopenings            rtahmass      0-1  A13
# 475        InnocuousMate            Neftegor      0-1  C00
# 479           gmlectures             Arteler      0-1  C15
# 486               micfel            rtahmass      0-1  B15
# 492              Arteler             ZQXY791      1-0  B30
# 494             Neftegor         Starbox2010      0-1  A06
#
#                                                opening    utc_date  utc_time  \
# 3    Ruy Lopez: Morphy Defense, Modern Steinitz Def...  2025.05.01  00:01:09
# 18   French Defense: Tarrasch Variation, Closed Var...  2025.05.01  00:03:57
# 41                                       Kádas Opening  2025.05.01  00:10:04
# 44            Sicilian Defense: Scheveningen Variation  2025.05.01  00:11:14
# 55   Caro-Kann Defense: Advance Variation, Botvinni...  2025.05.01  00:13:39
# 68   Queen's Gambit Declined: Exchange Variation, P...  2025.05.01  00:17:49
# 76         King's Indian Defense: Semi-Averbakh System  2025.05.01  00:20:02
# 81   Ruy Lopez: Open Berlin Defense, l'Hermet Varia...  2025.05.01  00:20:37
# 96                Caro-Kann Defense: Advance Variation  2025.05.01  00:23:32
# 117        King's Indian Defense: Semi-Averbakh System  2025.05.01  00:30:02
# 122  Caro-Kann Defense: Two Knights Attack, Mindeno...  2025.05.01  00:31:23
# 129        English Opening: Caro-Kann Defensive System  2025.05.01  00:33:10
# 138  Queen's Gambit Declined: Exchange Variation, P...  2025.05.01  00:34:48
# 150  French Defense: Tarrasch Variation, Open Syste...  2025.05.01  00:37:48
# 151              Caro-Kann Defense: Two Knights Attack  2025.05.01  00:37:54
# 170            Sicilian Defense: Kalashnikov Variation  2025.05.01  00:44:01
# 192                   Slav Defense: Exchange Variation  2025.05.01  00:47:49
# 203               Caro-Kann Defense: Advance Variation  2025.05.01  00:50:13
# 220  French Defense: Tarrasch Variation, Closed Var...  2025.05.01  00:53:44
# 221  Slav Defense: Exchange Variation, Symmetrical ...  2025.05.01  00:53:44
# 234                  Ruy Lopez: Open, Berlin Variation  2025.05.01  00:56:49
# 242        Queen's Gambit Declined: Exchange Variation  2025.05.01  00:58:09
# 247             King's Pawn Game: Wayward Queen Attack  2025.05.01  00:59:51
# 254  Caro-Kann Defense: Advance Variation, Short Va...  2025.05.01  01:02:26
# 258                   Slav Defense: Exchange Variation  2025.05.01  01:03:01
# 270  French Defense: Rubinstein Variation, Blackbur...  2025.05.01  01:05:32
# 277    Caro-Kann Defense: Panov Attack, Modern Defense  2025.05.01  01:08:33
# 296  Sicilian Defense: Kan Variation, Polugaevsky V...  2025.05.01  01:13:46
# 297  Caro-Kann Defense: Panov Attack, Fianchetto De...  2025.05.01  01:13:46
# 317              French Defense: Two Knights Variation  2025.05.01  01:20:01
# 318                                       Pirc Defense  2025.05.01  01:20:49
# 337  Caro-Kann Defense: Advance Variation, Tal Vari...  2025.05.01  01:25:38
# 340                      Slav Defense: Quiet Variation  2025.05.01  01:26:12
# 353                     Sicilian Defense: Old Sicilian  2025.05.01  01:30:50
# 364                 French Defense: Tarrasch Variation  2025.05.01  01:32:55
# 368  English Opening: Agincourt Defense, Catalan De...  2025.05.01  01:34:14
# 374                      Catalan Opening: Open Defense  2025.05.01  01:35:52
# 376                                       Wade Defense  2025.05.01  01:36:24
# 378  French Defense: Tarrasch Variation, Closed Var...  2025.05.01  01:37:16
# 398  French Defense: Tarrasch Variation, Open Syste...  2025.05.01  01:42:43
# 399                                  Trompowsky Attack  2025.05.01  01:42:57
# 423  French Defense: Tarrasch Variation, Morozevich...  2025.05.01  01:49:37
# 426                      Modern Defense: Standard Line  2025.05.01  01:50:03
# 442                  French Defense: Winawer Variation  2025.05.01  01:55:31
# 444                 French Defense: Exchange Variation  2025.05.01  01:55:52
# 446               Caro-Kann Defense: von Hennig Gambit  2025.05.01  01:57:00
# 461  Slav Defense: Exchange Variation, Trifunovic V...  2025.05.01  02:01:02
# 462  English Opening: Symmetrical Variation, Anti-B...  2025.05.01  02:01:09
# 464     Ruy Lopez: Morphy Defense, Mackenzie Variation  2025.05.01  02:01:41
# 467                Trompowsky Attack: Raptor Variation  2025.05.01  02:02:28
# 468  English Opening: Agincourt Defense, Catalan De...  2025.05.01  02:03:22
# 475               French Defense: King's Indian Attack  2025.05.01  02:05:16
# 479  French Defense: Winawer Variation, Alekhine-Ma...  2025.05.01  02:07:32
# 486                       Caro-Kann Defense: Main Line  2025.05.01  02:09:55
# 492                     Sicilian Defense: Old Sicilian  2025.05.01  02:10:55
# 494                                  Zukertort Opening  2025.05.01  02:11:36
#
#     time_control                                              moves
# 3          180+0  [e2e4, e7e5, g1f3, b8c6, f1b5, a7a6, b5a4, d7d...
# 18         180+0  [e2e4, e7e6, d2d4, d7d5, b1d2, g8f6, e4e5, f6d...
# 41         180+0  [h2h4, e7e5, h1h3, d7d5, c2c4, c8h3, g1h3, c7c...
# 44         180+0  [e2e4, c7c5, g1f3, d7d6, d2d4, c5d4, f3d4, g8f...
# 55         180+0  [e2e4, c7c6, d2d4, d7d5, e4e5, c6c5, c2c3, b8c...
# 68         180+0  [d2d4, g8f6, c2c4, e7e6, b1c3, d7d5, c4d5, e6d...
# 76         180+0  [d2d4, g8f6, c2c4, g7g6, b1c3, f8g7, e2e4, d7d...
# 81         180+0  [e2e4, e7e5, g1f3, b8c6, f1b5, g8f6, e1g1, f6e...
# 96         180+0  [e2e4, c7c6, d2d4, d7d5, e4e5, c8f5, b1d2, e7e...
# 117        180+0  [d2d4, g8f6, c2c4, g7g6, b1c3, f8g7, e2e4, e8g...
# 122        180+0  [e2e4, c7c6, g1f3, d7d5, b1c3, c8g4, h2h3, g4f...
# 129        180+0  [c2c4, c7c6, d1a4, d7d5, c4d5, d8d5, b1c3, d5d...
# 138        180+0  [d2d4, d7d5, c2c4, e7e6, b1c3, g8f6, c4d5, e6d...
# 150        180+0  [e2e4, e7e6, d2d4, d7d5, b1d2, c7c5, g1f3, c5d...
# 151        180+0  [e2e4, c7c6, b1c3, d7d5, g1f3, d5e4, c3e4, g8f...
# 170        180+0  [e2e4, c7c5, g1f3, b8c6, d2d4, c5d4, f3d4, e7e...
# 192        180+0  [d2d4, d7d5, c2c4, c7c6, c4d5, c6d5, c1f4, b8c...
# 203        180+0  [e2e4, c7c6, d2d4, d7d5, e4e5, c8f5, b1d2, e7e...
# 220        180+0  [e2e4, e7e6, d2d4, d7d5, b1d2, g8f6, e4e5, f6d...
# 221        180+0  [d2d4, d7d5, c2c4, c7c6, g1f3, g8f6, c4d5, c6d...
# 234        180+0  [e2e4, e7e5, g1f3, b8c6, f1b5, a7a6, b5a4, g8f...
# 242        180+0  [d2d4, d7d5, c2c4, e7e6, b1c3, g8f6, c4d5, f6d...
# 247        180+0  [e2e4, e7e6, d1e2, e6e5, e2h5, b8c6, f1c4, g7g...
# 254        180+0  [e2e4, c7c6, d2d4, d7d5, e4e5, c8f5, g1f3, e7e...
# 258        180+0  [d2d4, d7d5, c2c4, c7c6, c4d5, c6d5, c1f4, b8c...
# 270        180+0  [e2e4, e7e6, d2d4, d7d5, b1d2, d5e4, d2e4, b8d...
# 277        180+0  [e2e4, c7c6, d2d4, d7d5, e4d5, c6d5, c2c4, g8f...
# 296        180+0  [e2e4, c7c5, g1f3, e7e6, d2d4, c5d4, f3d4, a7a...
# 297        180+0  [e2e4, c7c6, d2d4, d7d5, e4d5, c6d5, c2c4, g8f...
# 317        180+0  [e2e4, e7e6, g1f3, d7d5, b1c3, d5d4, c3e2, c7c...
# 318        180+0  [e2e4, d7d6, f1c4, e7e6, b1c3, g8f6, d2d3, a7a...
# 337        180+0  [e2e4, c7c6, d2d4, d7d5, e4e5, c8f5, h2h4, h7h...
# 340        180+0  [g1f3, d7d5, d2d4, c7c6, c2c4, g8f6, e2e3, a7a...
# 353        180+0  [e2e4, c7c5, g1f3, b8c6, c2c3, g8f6, e4e5, f6d...
# 364        180+0  [e2e4, e7e6, d2d4, d7d5, b1d2, d5e4, d2e4, g8f...
# 368        180+0  [g1f3, g8f6, c2c4, e7e6, g2g3, d7d5, f1g2, d5c...
# 374        180+0  [g1f3, g8f6, c2c4, e7e6, g2g3, d7d5, d2d4, d5c...
# 376        180+2  [g1f3, d7d6, d2d4, c8g4, b1c3, g8f6, e2e4, c7c...
# 378        180+0  [e2e4, e7e6, d2d4, d7d5, b1d2, g8f6, e4e5, f6d...
# 398        180+0  [e2e4, e7e6, d2d4, d7d5, b1d2, c7c5, g1f3, c5d...
# 399        180+2  [d2d4, g8f6, c1g5, d7d5, b1d2, b8d7, e2e3, e7e...
# 423        180+0  [e2e4, e7e6, d2d4, d7d5, b1d2, f8e7, c2c3, c7c...
# 426        180+2  [e2e4, g7g6, d2d4, f8g7, b1c3, c7c6, f1c4, d7d...
# 442        180+0  [e2e4, e7e6, d2d4, d7d5, b1c3, f8b4, d1g4, g8f...
# 444        180+0  [e2e4, e7e6, g1f3, d7d5, e4d5, e6d5, d2d4, g8f...
# 446        180+0  [e2e4, c7c6, d2d4, d7d5, b1c3, d5e4, f1c4, g8f...
# 461        180+0  [d2d4, d7d5, c2c4, c7c6, c4d5, c6d5, b1c3, g8f...
# 462        180+0  [g1f3, g8f6, c2c4, c7c5, b1c3, b8c6, d2d4, c5d...
# 464        180+0  [e2e4, e7e5, g1f3, b8c6, f1b5, a7a6, b5a4, g8f...
# 467        180+2  [d2d4, g8f6, c1g5, f6e4, h2h4, c7c5, d4d5, d8b...
# 468        180+0  [g1f3, g8f6, c2c4, e7e6, g2g3, d7d5, f1g2, d5c...
# 475        180+0  [e2e4, e7e6, d2d3, d7d5, b1d2, g8f6, g1f3, b8c...
# 479        180+0  [e2e4, e7e6, b1c3, d7d5, d2d4, f8b4, g1e2, d5e...
# 486        180+0  [e2e4, c7c6, d2d4, d7d5, b1d2, d5e4, d2e4, g8f...
# 492        180+0  [e2e4, c7c5, g1f3, b8c6, c2c3, g8f6, e4e5, f6d...
# 494        180+0  [g1f3, d7d5, e2e3, c7c5, b2b3, b8c6, c1b2, c8g...

# %% [markdown]
# ## 4.2 Compute opening stats for White & Black

# %%
def compute_opening_stats(games_df: pd.DataFrame, color: str = 'white', min_games: int = 5) -> pd.DataFrame:
    """
    Compute opening statistics (frequency and performance) for a given color.

    Args:
        games_df: DataFrame already filtered to include only peer games,
                  with columns ['white','black','eco','opening','result'].
        color: 'white' or 'black' — which side the peer was playing.
        min_games: minimum games threshold to include an opening.

    Returns:
        DataFrame with columns [eco, opening, games_played, wins, draws, score_pct],
        sorted descending by score_pct then games_played.
    """
    if color not in ('white','black'):
        raise ValueError("color must be 'white' or 'black'")

    # Determine what result string counts as a win for this color
    win_str = '1-0' if color == 'white' else '0-1'
    draw_str = '1/2-1/2'

    stats = (
        games_df
        .groupby(['eco','opening'])
        .agg(
            games_played=('result','size'),
            wins=('result', lambda s: (s == win_str).sum()),
            draws=('result', lambda s: (s == draw_str).sum()),
        )
        .reset_index()
    )

    # Compute score percentage
    stats['score_pct'] = (stats['wins'] + 0.5 * stats['draws']) / stats['games_played']

    # Filter by minimum games and sort
    stats = stats[stats['games_played'] >= min_games]
    stats = stats.sort_values(['score_pct','games_played'], ascending=False).reset_index(drop=True)

    return stats

# %%
peer_list = top_peers['player'].tolist()

# Only games where the peer was White
white_peer_games = peer_games[peer_games['white'].isin(peer_list)]
white_stats = compute_opening_stats(white_peer_games, min_games=1)  # start with min_games=1 to see anything

# Only games where the peer was Black
black_peer_games = peer_games[peer_games['black'].isin(peer_list)]
black_stats = compute_opening_stats(black_peer_games, min_games=1)

print("Top White Recommendations:")
display(white_stats.head(5))

print("Top Black Recommendations:")
display(black_stats.head(5))
# Out:
# Top White Recommendations:
#    eco                                            opening  games_played  wins  \
# 0  B30                     Sicilian Defense: Old Sicilian             2     2
# 1  C06  French Defense: Tarrasch Variation, Closed Var...             2     2
# 2  A33  English Opening: Symmetrical Variation, Anti-B...             1     1
# 3  A45                                  Trompowsky Attack             1     1
# 4  B00                                       Pirc Defense             1     1
#
#    draws  score_pct
# 0      0        1.0
# 1      0        1.0
# 2      0        1.0
# 3      0        1.0
# 4      0        1.0
# Top Black Recommendations:
#    eco                                            opening  games_played  wins  \
# 0  C06  French Defense: Tarrasch Variation, Closed Var...             2     2
# 1  A00                                      Kádas Opening             1     1
# 2  A11        English Opening: Caro-Kann Defensive System             1     1
# 3  A41                                       Wade Defense             1     1
# 4  B11  Caro-Kann Defense: Two Knights Attack, Mindeno...             1     1
#
#    draws  score_pct
# 0      0        1.0
# 1      0        1.0
# 2      0        1.0
# 3      0        1.0
# 4      0        1.0

# %%
def recommend_openings(white_stats: pd.DataFrame, black_stats: pd.DataFrame, top_n: int = 3):
    """
    Select the top_n openings for White and Black based on peer stats.

    Args:
        white_stats: DataFrame from compute_opening_stats(color='white')
        black_stats: DataFrame from compute_opening_stats(color='black')
        top_n: number of openings to recommend per color

    Returns:
        Two lists of tuples: (eco, opening, games_played, score_pct) for White and Black.
    """
    white_top = white_stats.head(top_n)[['eco','opening','games_played','score_pct']]
    black_top = black_stats.head(top_n)[['eco','opening','games_played','score_pct']]

    return (
        list(white_top.itertuples(index=False, name=None)),
        list(black_top.itertuples(index=False, name=None))
    )

# %%
white_recs, black_recs = recommend_openings(white_stats, black_stats, top_n=3)

# %%
white_recs
# Out:
# [('B30', 'Sicilian Defense: Old Sicilian', 2, 1.0),
#  ('C06',
#   'French Defense: Tarrasch Variation, Closed Variation, Main Line',
#   2,
#   1.0),
#  ('A33',
#   'English Opening: Symmetrical Variation, Anti-Benoni Variation, Spielmann Defense',
#   1,
#   1.0)]

# %%
black_recs
# Out:
# [('C06',
#   'French Defense: Tarrasch Variation, Closed Variation, Main Line',
#   2,
#   1.0),
#  ('A00', 'Kádas Opening', 1, 1.0),
#  ('A11', 'English Opening: Caro-Kann Defensive System', 1, 1.0)]
